# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Preprocessing Data

# %%
# Look at arbitrary images in the dataset
for dirName, subdirList, fileList in os.walk('./lfw-deepfunneled/German_Khan'):
    for f in fileList:
        img = cv2.imread(os.path.join(dirName, f))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        print(img.shape)
        plt.imshow(img)
        plt.title(' '.join(dirName.split('/')[-1].split('_')))
# Out:
# (250, 250, 3)

# %%
img_count = 0
ppl_count = 0
for l in os.listdir('./lfw-deepfunneled'):
    if l != './lfw-deepfunneled' and l != '.DS_Store':
        ppl_count += 1
        dirName = os.path.join('./lfw-deepfunneled', l)
        #print(dirName, os.listdir(dirName))
        img_count += len(os.listdir(dirName))
print(f'Dataset contains {img_count} images from {ppl_count} people.')
# Out:
# Dataset contains 13233 images from 5749 people.

# %%
# use haar cascade to detect faces in the images
def crop_face(img):
    cropped_img = cv2.resize(img[61:189,61:189], (160,160))
    cropped_img = cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB)
    return cropped_img

# %%
# Display a few images after face detection and cropping
c = 0
fig, ax = plt.subplots(2,2)
idx = 0
for l in os.listdir('./lfw-deepfunneled'):
    if l != './lfw-deepfunneled' and l != '.DS_Store':
        for i in os.listdir(os.path.join('./lfw-deepfunneled',l)):
            img_name = os.path.join(os.path.join('./lfw-deepfunneled', l), i)
            img = cv2.imread(img_name)
            ax[idx//2,idx%2].imshow(crop_face(img))
            idx += 1
        c += 1
        if c > 3:
            break

# %%
# store faces of every person in the dataset
faces = []
ppl = []
for l in os.listdir('./lfw-deepfunneled'):
    if l != './lfw-deepfunneled' and l != '.DS_Store':
        for i in os.listdir(os.path.join('./lfw-deepfunneled',l)):
            img_name = os.path.join(os.path.join('./lfw-deepfunneled', l), i)
            person_name = img_name.split('/')[2]
            if not img_name.endswith('.DS_Store'):
                img = cv2.imread(img_name)
                cropped_img = crop_face(img)
                faces.append(cropped_img)
                ppl.append(person_name)

# %%
len(faces)
# Out:
# 13233

# %%
plt.imshow(faces[4302])
plt.title(ppl[4302])
# Out:
# Text(0.5, 1.0, 'James_Meredeth')

# %%
uniq_ppl = list(np.unique(ppl))
for i in range(len(ppl)):
    ppl[i] = uniq_ppl.index(ppl[i])

# %%
ppl = tf.keras.utils.to_categorical(ppl)
ppl.shape
# Out:
# (13233, 5749)

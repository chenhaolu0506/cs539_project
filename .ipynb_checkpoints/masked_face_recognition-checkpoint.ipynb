# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocessing Data

# %%
# Look at arbitrary images in the dataset
for dirName, subdirList, fileList in os.walk('./lfw/German_Khan'):
    for f in fileList:
        img = cv2.imread(os.path.join(dirName, f))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        print(img.shape)
        plt.imshow(img)
        plt.title(' '.join(dirName.split('/')[-1].split('_')))
# Out:
# (250, 250, 3)

# %%
img_count = 0
ppl_count = 0
for l in os.listdir('./lfw'):
    if l != './lfw' and l != '.DS_Store':
        ppl_count += 1
        dirName = os.path.join('./lfw', l)
        #print(dirName, os.listdir(dirName))
        img_count += len(os.listdir(dirName))
print(f'Dataset contains {img_count} images from {ppl_count} people.')
# Out:
# Dataset contains 13233 images from 5749 people.

# %%
# use haar cascade to detect faces in the images
clf = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gray_img.shape)
plt.imshow(gray_img,cmap=plt.cm.gray)
# Out:
# (250, 250)

# %%
faces = clf.detectMultiScale(gray_img, 1.1, 3)
for (x, y, w, h) in faces:
    cropped_img = img[x:x+w,y:y+w]
    #cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 1)
plt.imshow(cropped_img)

# %%
c = 0
fig, ax = plt.subplots(4, figsize=(15,15))
idx = 0
for l in os.listdir('./lfw'):
    if l != './lfw' and l != '.DS_Store':
        for i in os.listdir(os.path.join('./lfw',l)):
            img_name = os.path.join(os.path.join('./lfw', l), i)
            print(img_name)
            img = cv2.imread(img_name)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
            faces = clf.detectMultiScale(gray_img, 1.1, 3)
            for (x, y, w, h) in faces:
                cropped_img = img[x:x+w,y:y+w]
                #cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 1)
            ax[idx].imshow(cropped_img)
            idx += 1
        c += 1
        if c > 3:
            break

#TODO: write images in place to update dataset
# Out:
# ./lfw/German_Khan/German_Khan_0001.jpg
# ./lfw/Stefano_Gabbana/Stefano_Gabbana_0001.jpg
# ./lfw/Dragan_Covic/Dragan_Covic_0001.jpg
# ./lfw/Jeff_Hornacek/Jeff_Hornacek_0001.jpg
